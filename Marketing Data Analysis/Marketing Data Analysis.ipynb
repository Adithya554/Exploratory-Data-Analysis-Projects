# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#LOADING DATA
df=pd.read_csv('MarketingData.csv')

# %%
#LOOKING AT THE FIRST FEW ROWS OF THE TABLE
df.head(10)
# Out:
#    Yearly Income  No of kids at home  No of teenagers at home  \
# 0          58138                   0                        0
# 1          46344                   1                        1
# 2          71613                   0                        0
# 3          26646                   1                        0
# 4          58293                   1                        0
# 5          62513                   0                        1
# 6          55635                   0                        1
# 7          33454                   1                        0
# 8          30351                   1                        0
# 9           5648                   1                        1
#
#    Days since last purchase  AmtWines  AmtFruits  AmtMeatProducts  \
# 0                        58       635         88              546
# 1                        38        11          1                6
# 2                        26       426         49              127
# ...

# %%
#LOOKING AT A SUMMARY OF THE DATASET
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Yearly Income             249 non-null    int64
#  1   No of kids at home        249 non-null    int64
#  2   No of teenagers at home   249 non-null    int64
#  3   Days since last purchase  249 non-null    int64
#  4   AmtWines                  249 non-null    int64
#  5   AmtFruits                 249 non-null    int64
#  6   AmtMeatProducts           249 non-null    int64
#  7   AmtFishProducts           249 non-null    int64
#  8   AmtSweetProducts          249 non-null    int64
#  9   AmtRegularProds           249 non-null    int64
#  10  AmtGoldProds              249 non-null    int64
#  11  AmtTotal                  249 non-null    int64
#  12  NumDealsPurchases         249 non-null    int64
#  13  NumWebsitePurchases       249 non-null    int64
# ...

# %%
#CHECKING FOR MISSING VALUES
print(df.isnull().sum())
# Out:
# Yearly Income               0
# No of kids at home          0
# No of teenagers at home     0
# Days since last purchase    0
# AmtWines                    0
# AmtFruits                   0
# AmtMeatProducts             0
# AmtFishProducts             0
# AmtSweetProducts            0
# AmtRegularProds             0
# AmtGoldProds                0
# AmtTotal                    0
# NumDealsPurchases           0
# NumWebsitePurchases         0
# NumCatalogPurchases         0
# NumStorePurchases           0
# NumWebsiteVisitsMonth       0
# AcceptedCampaign3           0
# AcceptedCampaign1           0
# AcceptedCampaign2           0
# Age                         0
# Education                   0
# Marital Status              0
# dtype: int64

# %%
df.describe()
# Out:
#        Yearly Income  No of kids at home  No of teenagers at home  \
# count     249.000000          249.000000               249.000000
# mean    51840.855422            0.469880                 0.481928
# std     21764.884719            0.568047                 0.561423
# min      2447.000000            0.000000                 0.000000
# 25%     34176.000000            0.000000                 0.000000
# 50%     51369.000000            0.000000                 0.000000
# 75%     69142.000000            1.000000                 1.000000
# max    102692.000000            2.000000                 2.000000
#
#        Days since last purchase     AmtWines   AmtFruits  AmtMeatProducts  \
# count                249.000000   249.000000  249.000000       249.000000
# mean                  48.148594   299.461847   25.044177       167.919679
# std                   28.739479   328.624160   38.745682       238.921775
# min                    0.000000     0.000000    0.000000         1.000000
# ...

# %%
#1. Income
df['Yearly Income'].hist(bins=10)
plt.title("Income distribution")
plt.xlabel("Income")
plt.ylabel("Frequency")
plt.show()

# %%
#2.Age
df['Age'].hist(bins=10)
plt.title("Age distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
Graduate=Basic=none=Masters=PhD=0
for ed in df['Education']:
    if ed=="Graduation":
        Graduate=Graduate+1
    elif ed=="Masters":
        Masters=Masters+1
    elif ed=="PhD":
        PhD=PhD+1
    elif ed=="Basic":
        Basic=Basic+1
    else:
        none=none+1
Education=[none,Basic,Graduate,Masters,PhD]
levels=["None","Basic","Graduate","Masters","PhD"]
plt.bar(levels,height=Education)
plt.title("Education level distribution")
plt.xlabel("Level of Education")
plt.ylabel("Frequency");

# %%
df1=df[['AmtRegularProds','AmtWines','AmtFishProducts','AmtFruits','AmtSweetProducts','AmtTotal']].copy()
dataplot = sns.heatmap(df1.corr(), cmap="YlGnBu", annot=True)

# %%
plt.scatter(df['AmtWines'], df['AmtRegularProds'])
z=np.polyfit(df['AmtWines'],df['AmtRegularProds'],1)
p=np.poly1d(z)
plt.plot(df['AmtWines'],p(df['AmtWines']))
plt.title("Relationship between amount spent on wines and amount spent on regular products")
plt.xlabel("Amount spent on wines")
plt.ylabel("Amount spent on regular products");

# %%
plt.scatter(df['AmtWines'], df['AmtTotal'])
z=np.polyfit(df['AmtWines'],df['AmtTotal'],1)
p=np.poly1d(z)
plt.plot(df['AmtWines'],p(df['AmtWines']))
plt.title("Relationship between amount spent on wines and total amount spent.");

# %%
meat=df['AmtMeatProducts'].sum()
fish=df['AmtFishProducts'].sum()
fruits=df['AmtFruits'].sum()
sweet=df['AmtSweetProducts'].sum()
regular=df['AmtRegularProds'].sum()
wine=df['AmtWines'].sum()
l=[meat,fish,fruits,sweet,regular,wine]
plt.pie(l,labels=["Meat","Fish","Fruits","Sweets","Regular","Wine"],autopct='%.2f',radius=2);

# %%
df1=df[['NumCatalogPurchases','NumWebsitePurchases','NumStorePurchases','AmtTotal']].copy()
dataplot = sns.heatmap(df1.corr(), cmap="YlGnBu", annot=True)

# %%
plt.scatter(df['NumCatalogPurchases'], df['AmtTotal'])
z=np.polyfit(df['NumCatalogPurchases'],df['AmtTotal'],1)
p=np.poly1d(z)
plt.plot(df['NumCatalogPurchases'],p(df['NumCatalogPurchases']))
plt.title("Relationship between number of catalog purchases and total amount spent")
plt.xlabel("Number of catalog purchases")
plt.ylabel("Total amount spent");
